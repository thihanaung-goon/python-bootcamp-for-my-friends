# %% [markdown]
# # Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Operators

# %%
1 == 1
# Out:
# True

# %%
1 != 1
# Out:
# False

# %%
1 >= 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
'hello' in 'hello world'
# Out:
# True

# %%
'hello' not in 'hello world'
# Out:
# False

# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | False
# Out:
# False

# %%
(1 > 2) & (2 == 2)
# Out:
# False

# %%
True | False & True & False
# Out:
# True
