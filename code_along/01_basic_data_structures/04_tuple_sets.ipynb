# %% [markdown]
# # Tuple

# %%
my_tuple = (1, 2, 3)
my_tuple
# Out:
# (1, 2, 3)

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple[1]
# Out:
# 2

# %%
my_tuple[1] = 40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2d630ab5988d> in <module>()
# ----> 1 my_tuple[1] = 40
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Tuple methods

# %%
t = ('a', 'a', 'b', 'b', 'c')
t
# Out:
# ('a', 'a', 'b', 'b', 'c')

# %%
t.count('a')
# Out:
# 2

# %%
t.index('a')
# Out:
# 0

# %%
t.index('b')
# Out:
# 2

# %% [markdown]
# # Sets

# %%
my_set = set()
my_set
# Out:
# set()

# %%
my_set.add(1)
my_set
# Out:
# {1}

# %%
my_set.add(2)
my_set
# Out:
# {1, 2}

# %%
my_set.add(1)
my_set
# Out:
# {1, 2}

# %%
type(my_set)
# Out:
# set

# %%
my_list = [1, 1, 2, 2, 2, 2, 3, 3, 3, 4, 4, 4, 4]
set(my_list)
# Out:
# {1, 2, 3, 4}

# %%
set('aaabbbccccdddd')
# Out:
# {'a', 'b', 'c', 'd'}

# %%
my_set = set((1, 2, 2, 1, 3, 3))
my_set
# Out:
# {1, 2, 3}

# %%
my_set.update((3, 4, 4, 5, 'a'))
my_set
# Out:
# {1, 2, 3, 4, 5, 'a'}

# %%
my_set.remove('a')
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set.remove('a') # will get an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-723d8df69d8a> in <module>()
# ----> 1 my_set.remove('a') # will get an erro
#
# KeyError: 'a'

# %% [markdown]
# ## SET Operations

# %%
first_set = set([1, 2, 3, 4, 5])
second_set = set([4, 5, 6, 7, 8])

# %% [markdown]
# ### Union

# %%
first_set.union(second_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
first_set | second_set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ### Intersection

# %%
first_set.intersection(second_set)
# Out:
# {4, 5}

# %%
first_set & second_set
# Out:
# {4, 5}

# %% [markdown]
# ### Difference

# %%
first_set.difference(second_set)
# Out:
# {1, 2, 3}

# %%
first_set - second_set
# Out:
# {1, 2, 3}

# %%
second_set - first_set
# Out:
# {6, 7, 8}

# %% [markdown]
# ### Symmetric difference

# %%
first_set.symmetric_difference(second_set)
# Out:
# {1, 2, 3, 6, 7, 8}
