# %% [markdown]
# # Introduction

# %%
my_list = [1, 2, 3]
my_list
# Out:
# [1, 2, 3]

# %%
my_list = ['hello', 1, 2]
my_list
# Out:
# ['hello', 1, 2]

# %%
len(my_list)
# Out:
# 3

# %%
my_list = [[1,2,3], [4, 5, [6, 7]]]
len(my_list)
# Out:
# 2

# %% [markdown]
# ## Slicing and indexing

# %%
my_list = ['a', 'b', 'c', 'd', 'e', 'f']
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1:]
# Out:
# ['b', 'c', 'd', 'e', 'f']

# %%
# does not change after slicing or indexing
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
my_list[-1]
# Out:
# 'f'

# %%
my_list[2:4]
# Out:
# ['c', 'd']

# %% [markdown]
# ## Advanced indexing

# %%
my_list = [[1, 2, 3], [4, 5, 6]]
len(my_list)
# Out:
# 2

# %%
my_list[0]
# Out:
# [1, 2, 3]

# %%
my_list[0][1]
# Out:
# 2

# %%
my_list = [[1, 2, 3], ['a', 'b','c', [6, 7, [11, 12]]]]
len(my_list)
# Out:
# 2

# %%
my_list[1]
# Out:
# ['a', 'b', 'c', [6, 7, [11, 12]]]

# %%
my_list[1][3]
# Out:
# [6, 7, [11, 12]]

# %%
my_list[1][3][2]
# Out:
# [11, 12]

# %%
my_list[1][3][2][1]
# Out:
# 12

# %% [markdown]
# ## Concatenating

# %%
another_list = ['g', 'h', 'i']
my_list + another_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %% [markdown]
# **mutable**

# %%
new_list = ['one', 'two', 'three', 'four']
new_list
# Out:
# ['one', 'two', 'three', 'four']

# %%
new_list[0] = 'AAA'
new_list
# Out:
# ['AAA', 'two', 'three', 'four']

# %% [markdown]
# ## .append('append_item')

# %%
new_list.append('FIVE')
new_list
# Out:
# ['AAA', 'two', 'three', 'four', 'FIVE']

# %% [markdown]
# ## .insert(index, item)

# %%
new_list.insert(2, 'bbb')
new_list
# Out:
# ['AAA', 'two', 'bbb', 'three', 'four', 'FIVE']

# %% [markdown]
# ## .pop( )
# - remove the last element

# %%
new_list.pop()
# Out:
# 'FIVE'

# %%
new_list
# Out:
# ['AAA', 'two', 'bbb', 'three', 'four']

# %%
popped_item = new_list.pop() 
popped_item
# Out:
# 'four'

# %%
new_list
# Out:
# ['AAA', 'two', 'bbb', 'three']

# %% [markdown]
# **.pop(**index**)**

# %%
new_list.pop(1)
# Out:
# 'two'

# %%
new_list
# Out:
# ['AAA', 'bbb', 'three']

# %% [markdown]
# ## .sort( )

# %%
new_list = ['a','z', 'i', 'c', 'b']

# %%
new_list.sort()

# %%
# return None means return nothing
returned_value = new_list.sort()
returned_value

# %%
type(returned_value)
# Out:
# NoneType

# %%
new_list
# Out:
# ['a', 'b', 'c', 'i', 'z']

# %%
num_list = [10, 3, 6, 33, 200]
num_list.sort()
num_list
# Out:
# [3, 6, 10, 33, 200]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [200, 33, 10, 6, 3]
