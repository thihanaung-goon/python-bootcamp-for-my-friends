# %% [markdown]
# # String Exercises

# %% [markdown]
# 1. Fix the followings
#
# - Output should look like this.
#
# <pre>
# Day 1 - String Manipulation
# String Concatenation is done with the "+" sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash and n.
# </pre>

# %%
print(Day 1 - String")
print("String Concatenation is done with the "+" sign.")
  print('e.g. print("Hello " + "world")')
print(("New lines can be created with a backslash and n.")

# %% [markdown]
# ## Slicing and indexing

# %% [markdown]
# 2. Extract from the given sentence.

# %%
line = "This is a sentence."

# %% [markdown]
# > first letter

# %% [markdown]
# > last letter

# %% [markdown]
# > first four letter

# %% [markdown]
# > last four letter

# %% [markdown]
# > skip each one letter (တလုံးကျော်)
# <font color='blue'> Ti sasnec.

# %% [markdown]
# > reverse (ပြောင်းပြန်)
# <font color='blue'> .ecnetnes a si sihT

# %% [markdown]
# ## Some properties and methods

# %%
words_wrong = 'i LOve LEarnIng pYTHoN'

# %% [markdown]
# change `words_wrong` to `lower case letters` and assign to `words_lower` and print `words_wrong`.

# %%
# Out:
# i love learning python

# %% [markdown]
# Change the sentence like this `I love learning Python.`
#
# Hints
# 1. change the first letter `i` to `I`.
# 2. extract ` love learning ` included spaces before and after
# 3. change `p` to upper `P`
# 4. extract `ython`
# 5. add `.`

# %%
# Out:
# 'I love learning Python.'

# %% [markdown]
# ## f-string laterals

# %%
first_name = "john"
last_name = "SMITH"
age = 30

# %% [markdown]
# output looks like this.
# <pre>
# I'm John Smith.
# I am 30 years old.
# </pre>

# %% [markdown]
# print out ${\sqrt{2}}$ with 3 decimal place.

# %%
# Out:
# '1.414'
