# %% [markdown]
# ## Numbers

# %% [markdown]
# Answer the following three questions without typing code first. Then check your answer.
#
#
# - what is the value of
#   - 2 * ( 3 + 4 )
#   - 2 * 3 + 4
#   - 2 + 3 * 4

# %% [markdown]
# - What is the **type** of the result?
#
# > result = 1 + 1.4 + 1

# %% [markdown]
#  - Calculate the following
#  > ${8^3}$
#  > ${\sqrt{20}}$
#  > ${20 \div 3}$ ၏ အကြွင်း (modulus)
#  > ${20 \div 3}$ ၏ စားလဒ် (floor division)
