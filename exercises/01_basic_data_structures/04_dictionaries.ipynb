# %% [markdown]
# # Dictionary Exercises

# %% [markdown]
# 1. construct a dictionary with keys are `chicken, pig, cow` and values are `10, 4, 1`.

# %% [markdown]
# 2. extract all keys in a list.

# %% [markdown]
# 3. extract all values in a list.

# %% [markdown]
# 4. extract `catch me`.

# %%
my_dict = {'a': [1, 2, 'catch me']}

# %%
# Out:
# 'catch me'

# %%
my_dict = {'abc': 3, 'catch me': 'if you can'}

# %%
# Out:
# 'catch me'

# %%
my_dict = {
    'a': [1,2,3],
    'b': {
        'c': [2, 3, [4, 5, {'e': [6,5,4, [33, 'catch me']], 'f': [31, 23]}]]
    }
}

# %%
# Out:
# 'catch me'
