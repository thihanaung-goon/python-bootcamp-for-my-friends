# %% [markdown]
# # Boolean Exercises

# %% [markdown]
# **think about the answer before running the cell**

# %%
True & True

# %%
True | False

# %%
True & False

# %%
False & False

# %%
2 == 2 & 3 > 4

# %%
(2 == 2) & (3 > 4)

# %%
('A' in 'abc') | (3 < 2)

# %%
('b' not in 'abc') | (10 > 5)

# %%
('b' not in 'abc') & (10 > 5) | (3 != 3)

# %%
1900 % 10 == 0

# %%
(1900 % 400 == 0) | (1900 % 4 == 0) & (1900 % 100 != 0)
